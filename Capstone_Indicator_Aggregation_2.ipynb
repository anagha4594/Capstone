# %% [markdown]
# # Indicator Aggregation

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading the edited dataset
cap=pd.read_csv('Edited_std.csv',encoding='cp1252')
cap.head()
# Out:
#    Year    Country Name  \
# 0  1960  European Union
# 1  1961  European Union
# 2  1962  European Union
# 3  1963  European Union
# 4  1964  European Union
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                          -0.240377
# 1                                          -0.213048
# 2                                          -0.187328
# 3                                          -0.188559
# 4                                          -0.191342
#
#    Age dependency ratio (% of working-age population)  \
# 0                                          -0.337673
# 1                                          -0.307718
# 2                                          -0.294154
# 3                                          -0.290892
# 4                                          -0.287367
#
#    Age dependency ratio, old  Age dependency ratio, young  \
# 0                   0.176351                    -0.324912
# ...

# %%
# Shape of Standarized dataset
cap.shape
# Out:
# (1120, 172)

# %% [markdown]
# ## Indicators list and aggregation

# %%
# ACCESS TO CARE
# Diarrhea treatment (% of children under 5 receiving oral rehydration and continued feeding) not present
# Diarrhea treatment (% of children under 5 who received ORS packet) not present
# Improved sanitation facilities (% of population with access) is not present
# Improved sanitation facilities, rural (% of rural population with access) not present
#Improved sanitation facilities, urban (% of urban population with access) not present
#Maternal leave benefits (% of wages paid in covered period) not present
#Out-of-pocket health expenditure (% of private expenditure on health) not present
#Out-of-pocket health expenditure (% of total expenditure on health) not present
#Postnatal care coverage (% mothers) not present
#Unmet need for contraception (% of married women ages 15-49) not present
#Use of any antimalarial drug (% of pregnant women) not present
#Use of insecticide-treated bed nets (% of under-5 population) not present
#Use of Intermittent Preventive Treatment of malaria, 2+ doses of SP/Fansidar (% of pregnant women) not present
#Vitamin A supplementation coverage rate (% of children ages 6-59 months) not present

# %%
# AGEING AND LONG TERM CARE
fertility_rate_15_19=(cap['Adolescent fertility rate (births per 1,000 women ages 15-19)'])
fertility_rate_15_19=pd.DataFrame(fertility_rate_15_19)
fertility_rate_15_19.columns=['Adolescent Fertitlity rate(births per 1000 women ages 15-19)']                   

fertitlity_rate_total=cap['Fertility rate, total (births per woman)']
fertitlity_rate_total=pd.DataFrame(fertitlity_rate_total)
fertitlity_rate_total.columns=['Fertility rate, total (births per woman)']
# 'Female headed households (% of households with a female head)' not present

# %%
# HEALTH WORK FORCE
#Births attended by skilled health staff (% of total) not present
#Community health workers (per 1,000 people) not present
#Labor force, female (% of total labor force) not present
#Labor force, total not present
#Nurses and midwives (per 1,000 people) not present
#Specialist surgical workforce (per 100,000 population) not present



health_work_force=cap['Physicians (per 1,000 people)']
health_work_force=pd.DataFrame(health_work_force)
health_work_force.columns=['Health Workforce']

# %%
# HEALTH CARE ACTIVITIES
healthcare_activities=cap['Hospital beds (per 1,000 people)']
healthcare_activities=pd.DataFrame(healthcare_activities)
healthcare_activities.columns=['Healthcare Activities']
# 'Antiretroviral therapy coverage (% of people living with HIV)' not present
# 'Antiretroviral therapy coverage for PMTCT (% of pregnant women living with HIV)' not present
# 'ARI treatment (% of children under 5 taken to a health provider)' not presnt
# 'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)' not present
# 'Condom use with non regular partner, % adults(15-49), female' not present
# 'Condom use with non regular partner, % adults(15-49), male' not presnt
# 'Condom use, population ages 15-24, female (% of females ages 15-24)' not present
#'Condom use, population ages 15-24, male (% of males ages 15-24)' not present
#'Contraceptive prevalence, any methods (% of women ages 15-49)' not presnt
# 'Contraceptive prevalence, modern methods (% of women ages 15-49)' not presnt
# 'Improved water source (% of population with access)' not present
# 'Improved water source, rural (% of rural population with access)' not presnt
# 'Improved water source, urban (% of urban population with access)' not presnt
#'Newborns protected against tetanus (%)' not presnt
#'Number of surgical procedures (per 100,000 population)' not presnt
#'Pregnant women receiving prenatal care (%)' not presnt
#'Pregnant women receiving prenatal care of at least four visits (% of pregnant women)'
# 'Prevalence of anemia among children (% of children under 5)' not present
# 'Prevalence of anemia among non-pregnant women (% of women ages 15-49)' not presnt
# 'Prevalence of anemia among pregnant women (%)' not present
# 'Prevalence of anemia among women of reproductive age (% of women ages 15-49)' not presnt
# 'Prevalence of HIV, female (% ages 15-24)' not present
# 'Prevalence of HIV, male (% ages 15-24)' not presnt
# 'Prevalence of HIV, total (% of population ages 15-49)' not presnt
# 'Prevalence of overweight (% of adults)' not presnt
# 'Prevalence of overweight (% of children under 5)' not presnt
# 'Prevalence of overweight, female (% of children under 5)' not presnt
# Prevalence of overweight, female (% of female adults)' not presnt
#'Prevalence of overweight, male (% of children under 5) not presnt
# 'Prevalence of overweight, male (% of male adults)' not present
# 'Prevalence of severe wasting, weight for height (% of children under 5)' not present
# 'Prevalence of severe wasting, weight for height, female (% of children under 5)' not presnt
# 'Prevalence of severe wasting, weight for height, male (% of children under 5)' not presnt
# 'Prevalence of syphilis (% of women attending antenatal care)' not presnt
# 'Prevalence of tuberculosis (per 100,000 population)' not presnt
# 'Prevalence of undernourishment (% of population)' not present
# 'Prevalence of wasting (% of children under 5)' not presnt
# 'Prevalence of wasting, female (% of children under 5)' not present
# 'Prevalence of wasting, male (% of children under 5)' not present
#healthcare_activities[114:200]

# %%
# HEALTH EXPENDITURE
#External resources for health (% of total expenditure on health) not presnt
#GNI per capita, Atlas method (current US$) not present
#Health expenditure per capita (current US$) not present
#Health expenditure per capita, PPP not present
#Health expenditure, private (% of GDP) not present
#Health expenditure, private (% of total health expenditure) not presnt
#Health expenditure, public (% of GDP) not present
#Health expenditure, public (% of government expenditure) not present
#Health expenditure, public (% of total health expenditure) not present
#Health expenditure, total (% of GDP) not present
#Health expenditure, total (current US$) not present
#Public spending on education, total (% of GDP) not present
#Risk of catastrophic expenditure for surgical care (% of people at risk) not present
#Risk of impoverishing expenditure for surgical care (% of people at risk) not present

# %%
# Life Expectancy
meanlist=[]
for i in range(len(cap)):
    templist =[cap['Life expectancy at birth, female (years)'][i],cap['Life expectancy at birth, male (years)'][i],
               cap['Life expectancy at birth, total (years)'][i]]
    tempser = pd.Series(templist)
    #print(tempser)
    meanlist.append(tempser.mean())
    #print(meanlist)
    Life_Expectency=pd.DataFrame(meanlist)
    Life_Expectency.columns=['Life Expectency']

#Infant Mortality rate
meanlist=[]
for i in range(len(cap)):
    templist =[cap['Number of infant deaths'][i],cap['Number of under-five deaths'][i]]
    tempser = pd.Series(templist)
    #print(tempser)
    meanlist.append(tempser.mean())
    #print(meanlist)
    Infant_mortality=pd.DataFrame(meanlist)
    Infant_mortality.columns=['Infant Mortality']
    
    
# Avg Mortality Rate
# Mortality rate, adult, female (per 1,000 female adults)
#Mortality rate, adult, male (per 1,000 female adults)

Avg_Mortality_rate=(cap['Mortality rate, adult, female (per 1,000 female adults)']+
                    cap['Mortality rate, adult, male (per 1,000 male adults)'])/2
Avg_Mortality_rate=pd.DataFrame(Avg_Mortality_rate)
Avg_Mortality_rate.columns=['Avg Mortality Rate']    

# Mortality

Mortality_rate_female=cap['Mortality rate, adult, female (per 1,000 female adults)']
Mortality_rate_female=pd.DataFrame(Mortality_rate_female)
Mortality_rate_female.columns=['Mortality rate, adult, female']

Mortality_rate_male=cap['Mortality rate, adult, male (per 1,000 male adults)']
Mortality_rate_male=pd.DataFrame(Mortality_rate_male)
Mortality_rate_male.columns=['Mortality rate, adult, male']
    
#Age at first marriage, female not present
#Age at first marriage, male not present
#AIDS estimated deaths (UNAIDS estimates) not present
#Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total) not present
#Cause of death, by injury (% of total) not present
#Cause of death, by non-communicable diseases (% of total) not present
#Death rate, crude (per 1,000 people) not present
#Diabetes prevalence (% of population ages 20 to 79) not present
#Immunization, BCG (% of one-year-old children) not present
#Immunization, DPT (% of children ages 12-23 months) not present
#mmunization, HepB3 (% of one-year-old children) not present
#Immunization, Hib3 (% of children ages 12-23 months) not present
#Immunization, measles (% of children ages 12-23 months) not present
#munization, Pol3 (% of one-year-old children) not present
#Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months) not present
#Life expectancy at birth, total (years) not present
# Lifetime risk of maternal death (%) not present
#Lifetime risk of maternal death (1 in: rate varies by country) not present
#Maternal mortality ratio (modeled estimate, per 100,000 live births) not present
#Maternal mortality ratio (national estimate, per 100,000 live births) not present
#Mortality caused by road traffic injury (per 100,000 people) not present
#Mortality rate, infant, female (per 1,000 live births) not present
#Mortality rate, infant, male (per 1,000 live births) not present
#Mortality rate, neonatal (per 1,000 live births) not present
#Mortality rate, under-5, female (per 1,000) not present
#Mortality rate, under-5, male (per 1,000) not present
#Number of maternal deaths not present
#Number of neonatal deaths not present
#Number of weeks of maternity leave not present
#Tuberculosis death rate (per 100,000 people) not present
#health_status.isnull().sum()

# %%
# HEALTH STATUS FEMALE
Survival_to_age_65_female=cap['Survival to age 65, female (% of cohort)']
Survival_to_age_65_female=pd.DataFrame(Survival_to_age_65_female)
Survival_to_age_65_female.columns=['Survival to age 65 Female']

# %%
# HEALTH STATUS MALE
Survival_to_age_65_male=cap['Survival to age 65, male (% of cohort)']
Survival_to_age_65_male=pd.DataFrame(Survival_to_age_65_male)
Survival_to_age_65_male.columns=['Survival to age 65 Male']

# %%
#Survival to age 65 (% of cohort)
#Survival to age 65,female (% of cohort)
#Survival to age 65,male (% of cohort)
Survival_to_age_65=(cap['Survival to age 65, female (% of cohort)']+cap['Survival to age 65, male (% of cohort)'])/2
Survival_to_age_65=pd.DataFrame(Survival_to_age_65)
Survival_to_age_65.columns=['Survival to age 65 (% of cohort)']

# %%
#Survival to age 65 (% of cohort)
#Survival to age 65,female (% of cohort)
#Survival to age 65,male (% of cohort)
Survival_to_age_65_ratio=(cap['Survival to age 65, female (% of cohort)']/cap['Survival to age 65, male (% of cohort)'])
Survival_to_age_65_ratio=pd.DataFrame(Survival_to_age_65_ratio)
Survival_to_age_65_ratio.columns=['Survival to age 65 Ratio']

# %%
# INFANT HEALTH
# Low-birthweight babies (% of births) not present

# %%
# PHARMACEUTICAL SECTOR
# Consumption of iodized salt (% of households) not present

# %%
# Population
meanlist=[]
for i in range(len(cap)):
    templist =[cap['Population ages 00-14 (% of total)'][i],
               cap['Population ages 15-64 (% of total)'][i],
               cap['Population ages 65 and above (% of total)'][i],
               cap['Rural population (% of total population)'][i],
               cap['Urban population (% of total)'][i]]
    tempser = pd.Series(templist)
    #print(tempser)
    meanlist.append(tempser.mean())
    #print(meanlist)
    population=pd.DataFrame(meanlist)
    population.columns=['Overall Population']
len(meanlist)


meanlist=[]
for i in range(len(cap)):
    templist =[cap['Age dependency ratio (% of working-age population)'][i],
               cap['Age dependency ratio, old'][i],
               cap['Age dependency ratio, young'][i]]
    tempser = pd.Series(templist)
    #print(tempser)
    meanlist.append(tempser.mean())
    #print(meanlist)
    Age_dependency=pd.DataFrame(meanlist)
    Age_dependency.columns=['Age dependency Ratio']
len(meanlist)
# Out:
# 1120

# %%
#Population Female
meanlist=[]
for i in range(len(cap)):
    templist =[cap['Age population, age 0, female, interpolated'][i],
cap['Age population, age 01, female, interpolated'][i],
cap['Age population, age 02, female, interpolated'][i],
cap['Age population, age 03, female, interpolated'][i],
cap['Age population, age 04, female, interpolated'][i],
cap['Age population, age 05, female, interpolated'][i],
cap['Age population, age 06, female, interpolated'][i],
cap['Age population, age 07, female, interpolated'][i],
cap['Age population, age 08, female, interpolated'][i],
cap['Age population, age 09, female, interpolated'][i],
cap['Age population, age 10, female, interpolated'][i],
cap['Age population, age 11, female, interpolated'][i],
cap['Age population, age 12, female, interpolated'][i],
cap['Age population, age 13, female, interpolated'][i],
cap['Age population, age 14, female, interpolated'][i],
cap['Age population, age 15, female, interpolated'][i],
cap['Age population, age 16, female, interpolated'][i],
cap['Age population, age 17, female, interpolated'][i],
cap['Age population, age 18, female, interpolated'][i],
cap['Age population, age 19, female, interpolated'][i],
cap['Age population, age 20, female, interpolated'][i],
cap['Age population, age 21, female, interpolated'][i],
cap['Age population, age 22, female, interpolated'][i],
cap['Age population, age 23, female, interpolated'][i],
cap['Age population, age 24, female, interpolated'][i],
cap['Age population, age 25, female, interpolated'][i],
cap['Female population 00-04'][i],
cap['Female population 05-09'][i],
cap['Female population 10-14'][i],
cap['Female population 15-19'][i],
cap['Female population 20-24'][i],
cap['Female population 25-29'][i],
cap['Female population 30-34'][i],
cap['Female population 35-39'][i],
cap['Female population 40-44'][i],
cap['Female population 45-49'][i],
cap['Female population 50-54'][i],
cap['Female population 55-59'][i],
cap['Female population 60-64'][i],
cap['Female population 65-69'][i],
cap['Female population 70-74'][i],
cap['Female population 75-79'][i],
cap['Female population 80+'][i],
cap['Population ages 00-04, female (% of female population)'][i],
cap['Population ages 00-14, female (% of total)'][i],
cap['Population ages 0-14, female'][i],
cap['Population ages 05-09, female (% of female population)'][i],
cap['Population ages 10-14, female (% of female population)'][i],
cap['Population ages 15-19, female (% of female population)'][i],
cap['Population ages 15-64, female'][i],
cap['Population ages 15-64, female (% of total)'][i],
cap['Population ages 20-24, female (% of female population)'][i],
cap['Population ages 25-29, female (% of female population)'][i],
cap['Population ages 30-34, female (% of female population)'][i],
cap['Population ages 35-39, female (% of female population)'][i],
cap['Population ages 40-44, female (% of female population)'][i],
cap['Population ages 45-49, female (% of female population)'][i],
cap['Population ages 50-54, female (% of female population)'][i],
cap['Population ages 55-59, female (% of female population)'][i],
cap['Population ages 60-64, female (% of female population)'][i],
cap['Population ages 65 and above, female'][i],
cap['Population ages 65 and above, female (% of total)'][i],
cap['Population ages 65-69, female (% of female population)'][i],
cap['Population ages 70-74, female (% of female population)'][i],
cap['Population ages 75-79, female (% of female population)'][i],
cap['Population ages 80 and older, female (% of female population)'][i],
cap['Population, female'][i],
cap['Population, female (% of total)'][i]]
    tempser = pd.Series(templist)
    #print(tempser)
    meanlist.append(tempser.mean())
    #print(meanlist)
    population_female=pd.DataFrame(meanlist)
    population_female.columns=['Female Population']
len(meanlist)
# Out:
# 1120

# %%
# Population Male
meanlist=[]
for i in range(len(cap)):
    templist =[cap['Age population, age 0, male, interpolated'][i],
cap['Age population, age 01, male, interpolated'][i],
cap['Age population, age 02, male, interpolated'][i],
cap['Age population, age 03, male, interpolated'][i],
cap['Age population, age 04, male, interpolated'][i],
cap['Age population, age 05, male, interpolated'][i],
cap['Age population, age 06, male, interpolated'][i],
cap['Age population, age 07, male, interpolated'][i],
cap['Age population, age 08, male, interpolated'][i],
cap['Age population, age 09, male, interpolated'][i],
cap['Age population, age 10, male, interpolated'][i],
cap['Age population, age 11, male, interpolated'][i],
cap['Age population, age 12, male, interpolated'][i],
cap['Age population, age 13, male, interpolated'][i],
cap['Age population, age 14, male, interpolated'][i],
cap['Age population, age 15, male, interpolated'][i],
cap['Age population, age 16, male, interpolated'][i],
cap['Age population, age 17, male, interpolated'][i],
cap['Age population, age 18, male, interpolated'][i],
cap['Age population, age 19, male, interpolated'][i],
cap['Age population, age 20, male, interpolated'][i],
cap['Age population, age 21, male, interpolated'][i],
cap['Age population, age 22, male, interpolated'][i],
cap['Age population, age 23, male, interpolated'][i],
cap['Age population, age 24, male, interpolated'][i],
cap['Age population, age 25, male, interpolated'][i],
cap['Male population 00-04'][i],
cap['Male population 05-09'][i],
cap['Male population 10-14'][i],
cap['Male population 15-19'][i],
cap['Male population 20-24'][i],
cap['Male population 25-29'][i],
cap['Male population 30-34'][i],
cap['Male population 35-39'][i],
cap['Male population 40-44'][i],
cap['Male population 45-49'][i],
cap['Male population 50-54'][i],
cap['Male population 55-59'][i],
cap['Male population 60-64'][i],
cap['Male population 65-69'][i],
cap['Male population 70-74'][i],
cap['Male population 75-79'][i],
cap['Male population 80+'][i],
cap['Population ages 00-04, male (% of male population)'][i],
cap['Population ages 00-14, male (% of total)'][i],
cap['Population ages 0-14, male'][i],
cap['Population ages 05-09, male (% of male population)'][i],
cap['Population ages 15-19, male (% of male population)'][i],
cap['Population ages 15-64, male'][i],
cap['Population ages 15-64, male (% of total)'][i],
cap['Population ages 20-24, male (% of male population)'][i],
cap['Population ages 25-29, male (% of male population)'][i],
cap['Population ages 30-34, male (% of male population)'][i],
cap['Population ages 35-39, male (% of male population)'][i],
cap['Population ages 40-44, male (% of male population)'][i],
cap['Population ages 45-49, male (% of male population)'][i],
cap['Population ages 50-54, male (% of male population)'][i],
cap['Population ages 55-59, male (% of male population)'][i],
cap['Population ages 60-64, male (% of male population)'][i],
cap['Population ages 65 and above, male'][i],
cap['Population ages 65 and above, male (% of total)'][i],
cap['Population ages 65-69, male (% of male population)'][i],
cap['Population ages 70-74, male (% of male population)'][i],
cap['Population ages 75-79, male (% of male population)'][i],
cap['Population ages 80 and older, male (% of male population)'][i],
cap['Population ages10-14, male (% of male population)'][i],
cap['Population, male'][i],
cap['Population, male (% of total)'][i]]
    tempser = pd.Series(templist)
    #print(tempser)
    meanlist.append(tempser.mean())
    #print(meanlist)
    population_male=pd.DataFrame(meanlist)
    population_male.columns=['Male Population']
len(meanlist)
# Out:
# 1120

# %%
#Population aggregation
meanlist=[]
for i in range(len(cap)):
    templist =[cap['Female population 00-04'][i],
    cap['Female population 05-09'][i],
    cap['Female population 10-14'][i],
    cap['Female population 15-19'][i],
    cap['Female population 20-24'][i],
    cap['Female population 25-29'][i],
    cap['Female population 30-34'][i],
    cap['Female population 35-39'][i],
    cap['Female population 40-44'][i],
    cap['Female population 45-49'][i],
    cap['Female population 50-54'][i],
    cap['Female population 55-59'][i],
    cap['Female population 60-64'][i],
    cap['Female population 65-69'][i],
    cap['Female population 70-74'][i],
    cap['Female population 75-79'][i],
    cap['Female population 80+'][i]]
    templist_1=[cap['Male population 00-04'][i],
    cap['Male population 05-09'][i],
    cap['Male population 10-14'][i],
    cap['Male population 15-19'][i],
    cap['Male population 20-24'][i],
    cap['Male population 25-29'][i],
    cap['Male population 30-34'][i],
    cap['Male population 35-39'][i],
    cap['Male population 40-44'][i],
    cap['Male population 45-49'][i],
    cap['Male population 50-54'][i],
    cap['Male population 55-59'][i],
    cap['Male population 60-64'][i],
    cap['Male population 65-69'][i],
    cap['Male population 70-74'][i],
    cap['Male population 75-79'][i],
    cap['Male population 80+'][i]]
    tempser = pd.Series(templist).mean()
    tempser_1=pd.Series(templist_1).mean()
    #print(tempser)
    meanlist.append(tempser_1/tempser)
    #print(meanlist)
    Gender_balance=pd.DataFrame(meanlist)
    Gender_balance.columns=['Sex Ratio(Male to Female)']
len(meanlist)
# Out:
# 1120

# %%
#Population Growth Rate
#Birth rate, crude (per 1,000 people) 
#Death rate, crude (per 1,000 people)
population_growth_rate=cap['Birth rate, crude (per 1,000 people)']-cap['Death rate, crude (per 1,000 people)']
population_growth_rate=pd.DataFrame(population_growth_rate)
population_growth_rate.columns=['Population Growth Rate']

# %%
# POPULATION MALE/FEMALE
#'Sex ratio at birth (male births per female births)' not present

# %%
# QUALITY AND OUTCOME OF CARE
#Exclusive breastfeeding (% of children under 6 months) not present
#School enrollment, primary (% gross) not present
#School enrollment, primary (% net) not present
#School enrollment, primary, female (% gross) not present
#School enrollment, primary, female (% net) not present
#School enrollment, primary, male (% gross) not present
#School enrollment, primary, male (% net) not present
#School enrollment, secondary (% gross) not present
#School enrollment, secondary (% net) not present
#School enrollment, secondary, female (% gross) not present
#School enrollment, secondary, female (% net) not present
#School enrollment, secondary, male (% gross) not present
#School enrollment, secondary, male (% net) not present
#School enrollment, tertiary (% gross) not present
#School enrollment, tertiary, female (% gross) not present
#Tuberculosis treatment success rate (% of new cases) not present
#Literacy rate, adult female (% of females ages 15 and above) not present
#Literacy rate, adult male (% of males ages 15 and above) not present
#Literacy rate, adult total (% of people ages 15 and above) not present
#Literacy rate, youth male (% of males ages 15-24) not present
#Literacy rate, youth total (% of people ages 15-24) not present

# %%
# RISK FACTOR FOR HEALTH
#Smoking prevalence, females (% of adults) not present
#Smoking prevalence, males (% of adults) not present
#Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant) not present
#Tuberculosis case detection rate (all forms) not present
#Women's share of population ages 15+ living with HIV (%) not present
#Adults (ages 15+) and children (0-14 years) living with HIV
#Adults (ages 15+) and children (ages 0-14) newly infected with HIV
#Adults (ages 15+) living with HIV
#Adults (ages 15+) newly infected with HIV
#Children (0-14) living with HIV
#Children (ages 0-14) newly infected with HIV
#Children orphaned by HIV/AIDS
#Incidence of HIV (% of uninfected population ages 15-49)
#Incidence of tuberculosis (per 100,000 people)
#Malaria cases reported
#Malnutrition prevalence, height for age (% of children under 5)
#Malnutrition prevalence, height for age, female (% of children under 5)
#Malnutrition prevalence, height for age, male (% of children under 5)
#Malnutrition prevalence, weight for age (% of children under 5)
#Malnutrition prevalence, weight for age, female (% of children under 5)
#Malnutrition prevalence, weight for age, male (% of children under 5)
#Number of people who are undernourished
#People practicing open defecation (% of population)
#People practicing open defecation, rural (% of rural population)
#People practicing open defecation, urban (% of urban population)

# %%
# Creating the aggregated dataset
coun=cap[['Year','Country Name']]
Cap_new=pd.concat([coun,health_work_force,healthcare_activities,
                   fertility_rate_15_19,fertitlity_rate_total,
                   Survival_to_age_65_female,Survival_to_age_65_male,Survival_to_age_65,
                   Infant_mortality,Avg_Mortality_rate,Mortality_rate_female,Mortality_rate_male,
                   population,population_female,population_male,population_growth_rate,
                   Age_dependency,Gender_balance
                   ],axis=1)
Cap_new.head()
# Out:
#    Year    Country Name  Health Workforce  Healthcare Activities  \
# 0  1960  European Union               NaN                    NaN
# 1  1961  European Union               NaN                    NaN
# 2  1962  European Union               NaN                    NaN
# 3  1963  European Union               NaN                    NaN
# 4  1964  European Union               NaN                    NaN
#
#    Adolescent Fertitlity rate(births per 1000 women ages 15-19)  \
# 0                                          -0.240377
# 1                                          -0.213048
# 2                                          -0.187328
# 3                                          -0.188559
# 4                                          -0.191342
#
#    Fertility rate, total (births per woman)  Survival to age 65 Female  \
# 0                                 -0.175933                   0.118371
# 1                                 -0.168673                   0.156453
# ...

# %%
#
Cap_new.shape
# Out:
# (1120, 19)

# %%
Cap_new.count()
# Out:
# Year                                                            1120
# Country Name                                                    1120
# Health Workforce                                                 138
# Healthcare Activities                                             95
# Adolescent Fertitlity rate(births per 1000 women ages 15-19)    1100
# Fertility rate, total (births per woman)                        1100
# Survival to age 65 Female                                       1100
# Survival to age 65 Male                                         1100
# Survival to age 65 (% of cohort)                                1100
# Infant Mortality                                                 672
# Avg Mortality Rate                                              1022
# Mortality rate, adult, female                                   1022
# Mortality rate, adult, male                                     1022
# Overall Population                                              1120
# ...

# %%
Cap_new.to_csv('Indicator_Aggregated_21-03-2018.csv',index=False)

# %%
(Cap_new.isnull().sum()*100/len(Cap_new)).sort_values(ascending=False)
# Out:
# Healthcare Activities                                           91.517857
# Health Workforce                                                87.678571
# Infant Mortality                                                40.000000
# Mortality rate, adult, male                                      8.750000
# Mortality rate, adult, female                                    8.750000
# Avg Mortality Rate                                               8.750000
# Fertility rate, total (births per woman)                         1.785714
# Population Growth Rate                                           1.785714
# Adolescent Fertitlity rate(births per 1000 women ages 15-19)     1.785714
# Survival to age 65 (% of cohort)                                 1.785714
# Survival to age 65 Male                                          1.785714
# Survival to age 65 Female                                        1.785714
# Country Name                                                     0.000000
# ...
